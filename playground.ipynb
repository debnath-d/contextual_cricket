# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
paths = [
    Path("/", "home", "debnath", "Files", "cricsheet.org", "t20s_male_json"),
    Path("/", "storage2", "Files", "cricsheet.org", "t20s_male_json"),
]
for path in paths:
    if path.exists():
        data_dir = path
        break
else:
    print("No valid data directory found.")
    raise SystemExit(1)

index = pd.read_feather(data_dir.parent / "data" / "index.feather")

# %%
k: pd.Series = (index["date"].iloc[0] - index["date"]).dt.days.set_axis(index["id"])
k
# Out:
# id
# 211048        0
# 211028     -116
# 222678     -246
# 226374     -326
# 237242     -364
#            ...
# 1467706   -7313
# 1474260   -7316
# 1474261   -7317
# 1474262   -7318
# 1474263   -7320
# Name: date, Length: 2607, dtype: int64

# %%
plt.plot(-k, k * -1)

# %%
plt.plot(-k, 0.9996**k)

# %%
plt.plot(-k, 0.999**k)
